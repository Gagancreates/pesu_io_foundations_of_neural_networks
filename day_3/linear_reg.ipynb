# %% [markdown]
# # Day-3: Linear Regression Introduction
#
# In this notebook we will:
# 1. Start with a **toy dataset** (area vs. price).
# 2. Implement **Linear Regression functions from scratch**:
#    - `predict`
#    - `mse`
# 3. Visualize predictions vs. true values.
# 4. Explore how slope (`w`) and bias (`b`) affect errors.
# 5. Prepare intuition for **Gradient Descent** in Day 4.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Step 1: Create a Toy Dataset
#
# We simulate a dataset where **house price depends linearly on area**:
#
# \[
# y = w.x + b
# \]
#
# - `x` = area(in sqft)
# - `y` = price(in lakhs)
# - `w` = slope(lakhs per sqft)
# - `b` = intercept(base price)

# %%
# Toy dataset: Area (sqft) vs Price (lakhs)

X = np.array([500, 800, 1000, 1200, 1500, 1800, 2000, 2500])
y=np.array([ 70, 100, 120, 140, 170, 200, 220, 270])

print("Areas:", X)
print("Prices:", y)
# Out:
# Areas: [ 500  800 1000 1200 1500 1800 2000 2500]
# Prices: [ 70 100 120 140 170 200 220 270]

# %% [markdown]
# ## The task?
# ### To find the values of w and b such that `y=w.x + b`

# %%
# write the function to find prediction using the weights, x and bias b

# %% [markdown]
# ## Define MSE

# %%
#write a function to find mse using y_true and y_pred as parameters

# %% [markdown]
# ## Predict using a random value, find the best fitting line

# %%
y_pred = predict(X, 0.11, 220)

# %%
plt.scatter(X, y, color="blue", label="True Data")
plt.plot(X, y_pred, color="red", label="Prediction Line")
plt.xlabel("Area (sqft)")
plt.ylabel("Price (lakhs)")
plt.legend()
plt.show()
