# %% [markdown]
# # PyTorch Fundamentals - Assignment
#
# Complete all the exercises by filling in the code where indicated.

# %%
# Run this cell first
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
print(f"PyTorch version: {torch.__version__}")

# %% [markdown]
# ---
# ## Part 1: Tensor Creation
#
# ### Exercise 1.1
# Create the following tensors:
# - A 2x3 tensor of zeros
# - A 3x3 tensor of ones
# - A 1D tensor with values from 0 to 9

# %%
# YOUR CODE HERE
zeros_tensor = 
ones_tensor = 
range_tensor = 

# Test (don't modify)
print("Zeros:", zeros_tensor)
print("Ones:", ones_tensor)
print("Range:", range_tensor)

# %% [markdown]
# ### Exercise 1.2
# Create a tensor from the given list and convert it to float type.

# %%
data = [[1, 2, 3], [4, 5, 6]]

# YOUR CODE HERE
tensor_from_list = 

# Test (don't modify)
print(f"Tensor: {tensor_from_list}")
print(f"Data type: {tensor_from_list.dtype}")

# %% [markdown]
# ### Exercise 1.3
# Complete the function to create a random tensor with given shape and set the random seed for reproducibility.

# %%
def create_random_tensor(rows, cols, seed=42):
    """Create a random tensor of shape (rows, cols) with seed"""
    # YOUR CODE HERE
    
    
    return tensor

# Test (don't modify)
result = create_random_tensor(3, 4)
print(result)

# %% [markdown]
# ---
# ## Part 2: Tensor Operations
#
# ### Exercise 2.1
# Perform basic operations on the given tensors.

# %%
x = torch.tensor([[1, 2], [3, 4]], dtype=torch.float32)
y = torch.tensor([[5, 6], [7, 8]], dtype=torch.float32)

# YOUR CODE HERE
# Add x and y
addition = 

# Multiply each element of x by 3
scalar_mult = 

# Matrix multiply x and y
matrix_mult = 

# Test (don't modify)
print("Addition:\n", addition)
print("\nScalar multiplication:\n", scalar_mult)
print("\nMatrix multiplication:\n", matrix_mult)

# %% [markdown]
# ### Exercise 2.2
# Complete the function to compute mean, maximum, and minimum of a tensor.

# %%
def compute_stats(tensor):
    """Return mean, max, and min of the tensor"""
    # YOUR CODE HERE
    mean_val = 
    max_val = 
    min_val = 
    
    return mean_val, max_val, min_val

# Test (don't modify)
test_tensor = torch.tensor([1.5, 2.7, 3.2, 4.8, 5.1])
mean, max_v, min_v = compute_stats(test_tensor)
print(f"Mean: {mean}, Max: {max_v}, Min: {min_v}")

# %% [markdown]
# ### Exercise 2.3
# Perform indexing and slicing operations.

# %%
tensor = torch.arange(12).reshape(3, 4)
print("Original tensor:\n", tensor)

# YOUR CODE HERE
# Get the first row
first_row = 

# Get the second column
second_col = 

# Get the bottom-right 2x2 sub-tensor
sub_tensor = 

# Test (don't modify)
print("\nFirst row:", first_row)
print("Second column:", second_col)
print("Sub-tensor:\n", sub_tensor)

# %% [markdown]
# ---
# ## Part 3: Autograd
#
# ### Exercise 3.1
# Complete the code to compute gradients. Calculate the gradient of y = 3x² at x = 2.

# %%
# YOUR CODE HERE
# Create x with requires_grad=True
x = 

# Compute y = 3x²
y = 

# Compute gradient


# Test (don't modify)
print(f"x = {x.item()}")
print(f"y = {y.item()}")
print(f"dy/dx = {x.grad.item()}")
print(f"Expected dy/dx = 12 (because dy/dx = 6x = 6*2)")

# %% [markdown]
# ### Exercise 3.2
# Complete the function to compute gradients for: z = x² + y³

# %%
def compute_gradient(x_val, y_val):
    """
    Compute dz/dx and dz/dy where z = x² + y³
    """
    # YOUR CODE HERE
    x = 
    y = 
    
    # Compute z = x² + y³
    z = 
    
    # Backward pass
    
    
    return x.grad.item(), y.grad.item()

# Test (don't modify)
dx, dy = compute_gradient(3.0, 2.0)
print(f"At x=3, y=2:")
print(f"dz/dx = {dx} (expected: 6)")
print(f"dz/dy = {dy} (expected: 12)")
